# %% [markdown]
# Import necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Getting to know the Data

# %% [markdown]
# Import necessary Data Sets

# %%
petrol = pd.read_csv('cleaned_datasets/petrol_oilbarrel_prices.csv')
diesel = pd.read_csv('cleaned_datasets/diesel_oilbarrel_prices.csv')
oil_price = pd.read_csv('cleaned_datasets/oil_price.csv')

# %% [markdown]
# Check the datasets are suitable and cleaned

# %%
print(petrol.head())
print(petrol.info())
# Out:
#          Date  Barrel_oil_£  Petrol(pence/litre)  Petrol Dutyrate  petrol vat
# 0  2022-06-27     89.049618               190.93            52.95        20.0
# 1  2022-06-20     87.742586               186.85            52.95        20.0
# 2  2022-06-13     89.609124               182.53            52.95        20.0
# 3  2022-06-06     97.959906               174.99            52.95        20.0
# 4  2022-05-30     95.155435               170.36            52.95        20.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 989 non-null    object
#  1   Barrel_oil_£         989 non-null    float64
#  2   Petrol(pence/litre)  989 non-null    float64
#  3   Petrol Dutyrate      989 non-null    float64
#  4   petrol vat           989 non-null    float64
# dtypes: float64(4), object(1)
# ...

# %%
print(diesel.head())
print(diesel.info())
# Out:
#          Date  Barrel_oil_£  Diesel(pence/litre)  Diesel dutyrate  diesel vat
# 0  2022-06-27     89.049618               198.93            52.95        20.0
# 1  2022-06-20     87.742586               194.87            52.95        20.0
# 2  2022-06-13     89.609124               190.43            52.95        20.0
# 3  2022-06-06     97.959906               184.94            52.95        20.0
# 4  2022-05-30     95.155435               182.25            52.95        20.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 989 non-null    object
#  1   Barrel_oil_£         989 non-null    float64
#  2   Diesel(pence/litre)  989 non-null    float64
#  3   Diesel dutyrate      989 non-null    float64
#  4   diesel vat           989 non-null    float64
# dtypes: float64(4), object(1)
# ...

# %% [markdown]
# We need to convert the date column to an actual datetime format, pandas makes this easy

# %%
print(oil_price.info())
print(oil_price.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069 entries, 0 to 1068
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1069 non-null   object
#  1   Barrel_oil_£  1069 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 16.8+ KB
# None
#          Date  Barrel_oil_£
# 0  2022-06-27     89.049618
# 1  2022-06-20     87.742586
# 2  2022-06-13     89.609124
# 3  2022-06-06     97.959906
# 4  2022-05-30     95.155435

# %%
petrol['Date'] = pd.to_datetime(petrol['Date'], dayfirst=False)
diesel['Date'] = pd.to_datetime(diesel['Date'], dayfirst=False)
oil_price['Date'] = pd.to_datetime(oil_price['Date'], dayfirst=False)

# %%
print(petrol.info())
print(diesel.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 989 non-null    datetime64[ns]
#  1   Barrel_oil_£         989 non-null    float64
#  2   Petrol(pence/litre)  989 non-null    float64
#  3   Petrol Dutyrate      989 non-null    float64
#  4   petrol vat           989 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 38.8 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 989 non-null    datetime64[ns]
#  1   Barrel_oil_£         989 non-null    float64
#  2   Diesel(pence/litre)  989 non-null    float64
#  3   Diesel dutyrate      989 non-null    float64
# ...

# %% [markdown]
# Plot a line graph with the price of a barrel of oil and the price of a litre of petrol

# %%
plt.figure(figsize=(16,9))
plt.plot(petrol['Date'], petrol['Petrol(pence/litre)'], label='Petrol Price / Litre')
plt.plot(petrol['Date'], petrol['Barrel_oil_£'], label = 'Price of a barrel of Oil')
plt.plot(diesel['Date'], diesel['Diesel(pence/litre)'], label = 'Diesel Price / Litre')
plt.title('A graph to show the Change in price of Oil, Petrol and Diesel over time')
plt.ylabel('Price in £')
plt.xlabel('Date')
plt.legend()
plt.grid()
plt.savefig('PriceChanges.jpg')
plt.show()

# %% [markdown]
# # Variance from mean Price per year

# %%
def variance_per_year(dates, prices):
    pass

# %% [markdown]
# # Percentage Change Over Time

# %%
oil_price.sort_values('Date', ascending=True, inplace=True, ignore_index=True)
oil_price['Percent Change'] = oil_price['Barrel_oil_£'].pct_change() * 100
oil_price
# Out:
#            Date  Barrel_oil_£  Percent Change
# 0    2002-01-07     13.581168             NaN
# 1    2002-01-14     12.522600       -7.794381
# 2    2002-01-21     14.182905       13.258469
# 3    2002-01-28     14.376052        1.361830
# 4    2002-02-04     14.315716       -0.419698
# ...         ...           ...             ...
# 1064 2022-05-30     95.155435        4.358306
# 1065 2022-06-06     97.959906        2.947253
# 1066 2022-06-13     89.609124       -8.524694
# 1067 2022-06-20     87.742586       -2.082978
# 1068 2022-06-27     89.049618        1.489621
#
# [1069 rows x 3 columns]

# %%
petrol_price = petrol[['Date','Petrol(pence/litre)']]
petrol_price.sort_values('Date', ascending=True, inplace = True, ignore_index=True)
petrol_price['Percent Change'] = petrol_price['Petrol(pence/litre)'].pct_change() * 100
petrol_price
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# /var/folders/xg/h5_b_c714jnf6rp29g95jdp80000gn/T/ipykernel_4320/3071527128.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   petrol_price['Percent Change'] = petrol_price['Petrol(pence/litre)'].pct_change() * 100
#           Date  Petrol(pence/litre)  Percent Change
# 0   2003-06-09                74.59             NaN
# 1   2003-06-16                74.47       -0.160879
# ...

# %%
diesel_price = diesel[['Date','Diesel(pence/litre)']]
diesel_price.sort_values('Date', ascending=True, inplace = True, ignore_index=True)
diesel_price['Percent Change'] = diesel_price['Diesel(pence/litre)'].pct_change() * 100
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# /var/folders/xg/h5_b_c714jnf6rp29g95jdp80000gn/T/ipykernel_4320/177406030.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diesel_price['Percent Change'] = diesel_price['Diesel(pence/litre)'].pct_change() * 100

# %% [markdown]
# ##  Average Quarterly Growth

# %%
plt.figure(figsize=(16,9))
plt.plot(oil_price['Date'], oil_price['Percent Change'],  label='Change in Oil Price')
plt.plot(petrol_price['Date'], petrol_price['Percent Change'],  label='Change in Petrol Price')
plt.plot(diesel_price['Date'], diesel_price['Percent Change'],  label='Change in Diesel Price')
plt.xlabel('Year')
plt.ylabel('Percentage Change in Price')
plt.legend()
plt.grid()
plt.savefig('Percentage change in price over time.jpg')
plt.show()
plt.clf()

# %% [markdown]
# As this graph looks very messy, Well split the years into quarters instead of weeks and use the sum of the percent change and split it into subplots

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax1.plot(oil_price['Date'], oil_price['Percent Change'],  label='Change in Oil Price')
ax1.grid()
ax1.set_title('Percentage change in Price of Oil')
ax1.figure.savefig('Change in oil price.jpg')
ax2.plot(petrol_price['Date'], petrol_price['Percent Change'],  label='Change in Petrol Price', color='orange')
ax2.grid()
ax2.set_title('Percentage Change in Price of Petrol')
ax2.figure.savefig('Change in petrol price.jpg')
ax3.plot(diesel_price['Date'], diesel_price['Percent Change'],  label='Change in Diesel Price', color='green')
ax3.set_title('Percentage Change in Price of Diesel')
ax3.grid()
ax3.figure.savefig('Change in oil price.jpg')
plt.show()

# %% [markdown]
# ## Average percentage change

# %%
def avg_pcnt_change(series):
    mean = series.mean()
    return mean

oil_avg = avg_pcnt_change(oil_price['Percent Change'])
print(f'Average oil change in price: {oil_avg}')

petrol_avg = avg_pcnt_change(petrol_price['Percent Change'])
print(f'Average petrol change in price: {petrol_avg}')

diesel_avg = avg_pcnt_change(diesel_price['Percent Change'])
print(f'Average petrol change in price: {diesel_avg}')
# Out:
# Average oil change in price: 0.3171124685381692
# Average petrol change in price: 0.09849217198680868
# Average petrol change in price: 0.09922157348808529

# %% [markdown]
# ## Average percent change by year

# %%
oil_price['Quarter'] = oil_price['Date'].dt.to_period('Q')
petrol_price['Quarter'] = petrol_price['Date'].dt.to_period('Q')
diesel_price['Quarter'] = diesel_price['Date'].dt.to_period('Q')
# Out:
# /var/folders/xg/h5_b_c714jnf6rp29g95jdp80000gn/T/ipykernel_4320/1690604526.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   petrol_price['Quarter'] = petrol_price['Date'].dt.to_period('Q')
# /var/folders/xg/h5_b_c714jnf6rp29g95jdp80000gn/T/ipykernel_4320/1690604526.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diesel_price['Quarter'] = diesel_price['Date'].dt.to_period('Q')

# %%
sum_oil_pc = oil_price.groupby('Quarter')['Percent Change'].sum().reset_index()
sum_petrol_pc =petrol_price.groupby('Quarter')['Percent Change'].sum().reset_index()
sum_diesel_pc =diesel_price.groupby('Quarter')['Percent Change'].sum().reset_index()
merge_sum = sum_oil_pc.merge(sum_petrol_pc, how='inner', on='Quarter')
merge_sum = merge_sum.merge(sum_diesel_pc, how='inner', on='Quarter')
merged = merge_sum.rename(columns={'Percent Change_x': 'Oil Percentage Change', 'Percent Change_y': 'Petrol Percentage Change', 'Percent Change': 'Diesel Percentage Change'})
merged
# Out:
#    Quarter  Oil Percentage Change  Petrol Percentage Change  \
# 0   2003Q2               1.853900                 -0.322081
# 1   2003Q3               2.089074                  2.310088
# 2   2003Q4               0.338748                 -0.180368
# 3   2004Q1               4.436709                  2.156852
# 4   2004Q2              12.062391                  3.626066
# ..     ...                    ...                       ...
# 72  2021Q2              20.782066                  4.387565
# 73  2021Q3               4.262652                  3.363434
# 74  2021Q4               0.417387                  7.005864
# 75  2022Q1              36.149546                 11.754152
# 76  2022Q2              17.556210                 16.241409
#
#     Diesel Percentage Change
# 0                  -0.339050
# 1                   1.328489
# 2                   0.091175
# 3                   1.807076
# 4                   2.598199
# ..                       ...
# 72                  3.763632
# ...

# %%
x = range(len(merged))
plt.figure(figsize=(16,9))
plt.plot(x, merged['Oil Percentage Change'], label='Oil')
plt.plot(x,merged['Petrol Percentage Change'], label='Petrol')
plt.plot(x, merged['Diesel Percentage Change'], label='Diesel')
plt.ylabel('Percentage Change')
plt.title('Percentage Change by Quarter')
plt.xticks([])
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Correlation
